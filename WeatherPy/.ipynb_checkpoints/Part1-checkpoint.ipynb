# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
##pip install citipy==0.0.5
# Out:
# Requirement already satisfied: citipy==0.0.5 in c:\users\jeawills\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\jeawills\anaconda3\lib\site-packages (from citipy==0.0.5) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json 
from pandas.io.json import json_normalize

from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_names = []
lat = []
lon =[]
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

print('Beginning Data Retrieval ')
print('----------------------')
record = 1
for city in cities:
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"
    response = requests.get(url).json()
    try:
        city_names.append(response['name'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt']) 
        print(f'processing record {record} | {city}')
        record +=1 
        time.sleep(1.1)
    except:
        print ('city not found skipping....')
# Out:
# Beginning Data Retrieval
# ----------------------
# processing record 1 | cascais
# processing record 2 | bluff
# processing record 3 | majene
# processing record 4 | bathsheba
# city not found skipping....
# city not found skipping....
# processing record 5 | barrow
# processing record 6 | albany
# processing record 7 | mataura
# processing record 8 | hermanus
# processing record 9 | saint-philippe
# processing record 10 | nisia floresta
# processing record 11 | provideniya
# processing record 12 | henties bay
# city not found skipping....
# processing record 13 | bredasdorp
# processing record 14 | poso
# processing record 15 | kaitangata
# processing record 16 | makakilo city
# processing record 17 | gambela
# processing record 18 | mae sot
# processing record 19 | leningradskiy
# processing record 20 | rikitea
# processing record 21 | busselton
# processing record 22 | hithadhoo
# processing record 23 | tatarsk
# processing record 24 | ushuaia
# processing record 25 | grand gaube
# processing record 26 | saldanha
# processing record 27 | baruun-urt
# processing record 28 | nantucket
# processing record 29 | georgetown
# processing record 30 | kapaa
# processing record 31 | hobart
# processing record 32 | korla
# processing record 33 | bairiki
# processing record 34 | castro
# processing record 35 | minbu
# city not found skipping....
# processing record 36 | cape town
# processing record 37 | lompoc
# processing record 38 | norman wells
# processing record 39 | itacurubi del rosario
# processing record 40 | mitsamiouli
# processing record 41 | antofagasta
# processing record 42 | kangaatsiaq
# processing record 43 | vaini
# processing record 44 | tual
# processing record 45 | jiuquan
# processing record 46 | yellowknife
# processing record 47 | butaritari
# processing record 48 | kaduqli
# processing record 49 | ixtapa
# processing record 50 | acapulco
# processing record 51 | port macquarie
# processing record 52 | victoria
# processing record 53 | alugan
# processing record 54 | touros
# processing record 55 | port alfred
# processing record 56 | cherskiy
# processing record 57 | husavik
# processing record 58 | khuzhir
# processing record 59 | vostok
# processing record 60 | grindavik
# processing record 61 | mosquera
# city not found skipping....
# processing record 62 | qasigiannguit
# city not found skipping....
# city not found skipping....
# processing record 63 | inirida
# processing record 64 | terrak
# processing record 65 | staryy nadym
# processing record 66 | opole
# processing record 67 | namatanai
# processing record 68 | jamestown
# processing record 69 | udachnyy
# processing record 70 | guadalupe y calvo
# processing record 71 | kununurra
# processing record 72 | vestmannaeyjar
# processing record 73 | maniitsoq
# processing record 74 | puerto ayora
# processing record 75 | nelson bay
# processing record 76 | zaraza
# processing record 77 | quatre cocos
# processing record 78 | hauterive
# processing record 79 | palana
# processing record 80 | necochea
# processing record 81 | ucluelet
# city not found skipping....
# processing record 82 | duminichi
# processing record 83 | iqaluit
# processing record 84 | katsuura
# processing record 85 | kokoda
# processing record 86 | longyearbyen
# processing record 87 | ostrovnoy
# city not found skipping....
# processing record 88 | santander
# processing record 89 | tasiilaq
# processing record 90 | punta arenas
# city not found skipping....
# processing record 91 | esperance
# processing record 92 | bubaque
# processing record 93 | mawlaik
# processing record 94 | severo-kurilsk
# processing record 95 | fairbanks
# processing record 96 | zhigalovo
# processing record 97 | saskylakh
# processing record 98 | hovd
# processing record 99 | kahului
# processing record 100 | beringovskiy
# processing record 101 | tuktoyaktuk
# processing record 102 | avarua
# processing record 103 | novyy urengoy
# processing record 104 | zapolyarnyy
# processing record 105 | atuona
# processing record 106 | oistins
# processing record 107 | evensk
# processing record 108 | victor harbor
# processing record 109 | pajan
# processing record 110 | moyale
# processing record 111 | hilo
# processing record 112 | westport
# processing record 113 | nanortalik
# processing record 114 | nouakchott
# processing record 115 | chuy
# processing record 116 | kruisfontein
# processing record 117 | khatanga
# city not found skipping....
# processing record 118 | mahebourg
# processing record 119 | matara
# processing record 120 | nabire
# processing record 121 | pevek
# processing record 122 | lethem
# processing record 123 | chokurdakh
# processing record 124 | ovsyanka
# processing record 125 | samarai
# processing record 126 | pacific grove
# processing record 127 | hasaki
# processing record 128 | saint-pierre
# processing record 129 | turan
# processing record 130 | portland
# city not found skipping....
# processing record 131 | rudnichnyy
# processing record 132 | upernavik
# processing record 133 | bengkulu
# processing record 134 | guararapes
# processing record 135 | kasama
# processing record 136 | isangel
# processing record 137 | iberia
# city not found skipping....
# processing record 138 | bentiu
# processing record 139 | ambon
# processing record 140 | ishigaki
# processing record 141 | nikolskoye
# processing record 142 | laguna
# city not found skipping....
# processing record 143 | urengoy
# processing record 144 | bridlington
# processing record 145 | new norfolk
# processing record 146 | ribeira grande
# processing record 147 | khash
# processing record 148 | bud
# processing record 149 | aguilas
# processing record 150 | kodiak
# processing record 151 | san javier
# processing record 152 | verkhnevilyuysk
# processing record 153 | madaoua
# processing record 154 | carutapera
# processing record 155 | merauke
# processing record 156 | gidole
# processing record 157 | kosh-agach
# processing record 158 | nagua
# processing record 159 | baykit
# processing record 160 | kristiinankaupunki
# processing record 161 | chesapeake
# processing record 162 | gaoua
# processing record 163 | vila
# processing record 164 | qaanaaq
# processing record 165 | hirna
# processing record 166 | las palmas
# processing record 167 | lingao
# processing record 168 | sao filipe
# processing record 169 | abdanan
# processing record 170 | nanchong
# processing record 171 | pisco
# processing record 172 | ponta do sol
# processing record 173 | penzance
# processing record 174 | thompson
# processing record 175 | soderhamn
# processing record 176 | arenzano
# processing record 177 | bilibino
# processing record 178 | marawi
# processing record 179 | muyezerskiy
# processing record 180 | salalah
# city not found skipping....
# processing record 181 | bull savanna
# processing record 182 | itatskiy
# processing record 183 | bida
# processing record 184 | porto novo
# processing record 185 | arraial do cabo
# processing record 186 | lazaro cardenas
# processing record 187 | katherine
# processing record 188 | grao mogol
# processing record 189 | nouadhibou
# processing record 190 | marovoay
# processing record 191 | lashio
# city not found skipping....
# processing record 192 | brookhaven
# processing record 193 | grande-synthe
# processing record 194 | kloulklubed
# city not found skipping....
# processing record 195 | aklavik
# processing record 196 | bulungu
# processing record 197 | dongsheng
# processing record 198 | mao
# processing record 199 | mumford
# processing record 200 | itoman
# processing record 201 | salta
# processing record 202 | kikwit
# processing record 203 | chara
# processing record 204 | adamas
# city not found skipping....
# processing record 205 | mount isa
# processing record 206 | hami
# processing record 207 | cabo san lucas
# city not found skipping....
# processing record 208 | perth
# processing record 209 | geraldton
# processing record 210 | margate
# processing record 211 | kasongo-lunda
# processing record 212 | de-kastri
# processing record 213 | cootamundra
# processing record 214 | prince rupert
# processing record 215 | camana
# processing record 216 | sterling
# processing record 217 | lorengau
# processing record 218 | chapais
# processing record 219 | torbay
# processing record 220 | rocky mountain house
# processing record 221 | bazarnyy syzgan
# processing record 222 | altamont
# processing record 223 | venice
# processing record 224 | lavrentiya
# processing record 225 | kiama
# processing record 226 | nurota
# city not found skipping....
# processing record 227 | berlevag
# processing record 228 | hervey bay
# processing record 229 | hamilton
# processing record 230 | sao joao da barra
# processing record 231 | bayonne
# processing record 232 | naze
# processing record 233 | faya
# city not found skipping....
# processing record 234 | srednekolymsk
# city not found skipping....
# processing record 235 | san carlos de bariloche
# city not found skipping....
# processing record 236 | carnarvon
# processing record 237 | dawei
# processing record 238 | tiksi
# processing record 239 | brae
# processing record 240 | nojorid
# processing record 241 | dikson
# processing record 242 | romny
# city not found skipping....
# processing record 243 | chama
# processing record 244 | kavaratti
# processing record 245 | dudinka
# city not found skipping....
# processing record 246 | gisborne
# processing record 247 | araceli
# processing record 248 | jinchang
# processing record 249 | murdochville
# processing record 250 | khawhai
# processing record 251 | dubai
# processing record 252 | paamiut
# processing record 253 | changji
# processing record 254 | sulejowek
# processing record 255 | kota bahru
# processing record 256 | mgachi
# processing record 257 | tautira
# processing record 258 | koslan
# processing record 259 | mar del plata
# processing record 260 | north bend
# processing record 261 | ilulissat
# processing record 262 | richards bay
# processing record 263 | lebu
# processing record 264 | boksitogorsk
# processing record 265 | zyryanka
# processing record 266 | vestmanna
# processing record 267 | biggar
# processing record 268 | adrar
# processing record 269 | khudumelapye
# processing record 270 | eenhana
# processing record 271 | tacoronte
# processing record 272 | bukama
# processing record 273 | fukue
# city not found skipping....
# processing record 274 | mbandaka
# processing record 275 | tuatapere
# processing record 276 | batagay-alyta
# city not found skipping....
# processing record 277 | port-gentil
# processing record 278 | kyabe
# processing record 279 | dicabisagan
# processing record 280 | ventspils
# city not found skipping....
# processing record 281 | kokopo
# processing record 282 | lagoa
# processing record 283 | hambantota
# processing record 284 | port loko
# processing record 285 | flinders
# processing record 286 | alice springs
# processing record 287 | ndele
# processing record 288 | basco
# processing record 289 | cidreira
# processing record 290 | ulaangom
# city not found skipping....
# processing record 291 | fasa
# processing record 292 | araouane
# processing record 293 | dunedin
# processing record 294 | pridonskoy
# processing record 295 | marrakesh
# processing record 296 | clyde river
# processing record 297 | petrivka
# processing record 298 | mpanda
# processing record 299 | mount gambier
# processing record 300 | road town
# processing record 301 | krasnoye
# processing record 302 | havoysund
# processing record 303 | codrington
# processing record 304 | yamada
# processing record 305 | luanda
# processing record 306 | fortuna
# processing record 307 | pangnirtung
# processing record 308 | los llanos de aridane
# processing record 309 | ahipara
# processing record 310 | chapleau
# processing record 311 | mnogovershinnyy
# processing record 312 | opuwo
# processing record 313 | saquena
# processing record 314 | santa isabel do rio negro
# processing record 315 | axim
# city not found skipping....
# processing record 316 | saint-louis
# processing record 317 | linfen
# processing record 318 | walvis bay
# processing record 319 | feldru
# processing record 320 | lagos
# processing record 321 | northam
# processing record 322 | klaksvik
# processing record 323 | corrales
# processing record 324 | usinsk
# processing record 325 | norfolk
# processing record 326 | kutum
# processing record 327 | marzuq
# processing record 328 | lerwick
# processing record 329 | bambous virieux
# processing record 330 | vung tau
# processing record 331 | gamba
# processing record 332 | port elizabeth
# city not found skipping....
# processing record 333 | nicoya
# processing record 334 | namibe
# processing record 335 | kaz
# processing record 336 | darlowo
# processing record 337 | san rafael
# city not found skipping....
# processing record 338 | atasu
# processing record 339 | raga
# processing record 340 | tanete
# processing record 341 | aras
# processing record 342 | deer lake
# processing record 343 | oktyabrskoye
# processing record 344 | guaxupe
# city not found skipping....
# processing record 345 | port hedland
# processing record 346 | vao
# processing record 347 | banikoara
# processing record 348 | balkanabat
# processing record 349 | kwekwe
# processing record 350 | tilichiki
# processing record 351 | iturama
# processing record 352 | morehead
# processing record 353 | wakkanai
# processing record 354 | russell
# processing record 355 | nome
# processing record 356 | vryburg
# city not found skipping....
# processing record 357 | puerto rico
# processing record 358 | glyadyanskoye
# processing record 359 | souillac
# processing record 360 | la rioja
# processing record 361 | lahij
# processing record 362 | saint george
# processing record 363 | flin flon
# city not found skipping....
# processing record 364 | raudeberg
# processing record 365 | pampa
# processing record 366 | east london
# processing record 367 | nevelsk
# processing record 368 | manzanillo
# processing record 369 | governador valadares
# processing record 370 | tibiao
# processing record 371 | carbonia
# processing record 372 | trincomalee
# processing record 373 | college
# processing record 374 | krasnoselkup
# processing record 375 | meulaboh
# processing record 376 | pontianak
# processing record 377 | coihaique
# processing record 378 | kalabo
# processing record 379 | jalingo
# processing record 380 | kiruna
# processing record 381 | asau
# processing record 382 | kyshtovka
# processing record 383 | baiyin
# processing record 384 | sampit
# processing record 385 | renukut
# city not found skipping....
# processing record 386 | cap malheureux
# processing record 387 | baglan
# processing record 388 | beloha
# city not found skipping....
# processing record 389 | carandai
# processing record 390 | moose factory
# processing record 391 | manggar
# processing record 392 | price
# processing record 393 | byron bay
# processing record 394 | rabat
# processing record 395 | tweed
# processing record 396 | aizawl
# processing record 397 | broager
# processing record 398 | goksun
# processing record 399 | bethel
# processing record 400 | kavieng
# processing record 401 | aksarka
# processing record 402 | luderitz
# processing record 403 | orlik
# processing record 404 | faanui
# processing record 405 | likasi
# processing record 406 | constitucion
# processing record 407 | viedma
# processing record 408 | mogadishu
# processing record 409 | xining
# city not found skipping....
# processing record 410 | mahajanga
# processing record 411 | steinbach
# processing record 412 | gizo
# processing record 413 | waingapu
# processing record 414 | askino
# processing record 415 | laukaa
# processing record 416 | malindi
# processing record 417 | virginia beach
# processing record 418 | akdepe
# processing record 419 | the hammocks
# processing record 420 | aquiraz
# processing record 421 | ovre ardal
# processing record 422 | nizhniy chir
# processing record 423 | marsh harbour
# processing record 424 | balabac
# processing record 425 | kedrovyy
# processing record 426 | toamasina
# city not found skipping....
# processing record 427 | emerald
# processing record 428 | poum
# processing record 429 | mana
# processing record 430 | san joaquin
# processing record 431 | gobabis
# processing record 432 | sobolevo
# processing record 433 | popondetta
# processing record 434 | gospic
# processing record 435 | comodoro rivadavia
# processing record 436 | oliva
# processing record 437 | san quintin
# city not found skipping....
# processing record 438 | chhatapur
# city not found skipping....
# processing record 439 | west bay
# processing record 440 | broken hill
# city not found skipping....
# processing record 441 | lancut
# processing record 442 | manta
# processing record 443 | sfantu gheorghe
# processing record 444 | vallenar
# processing record 445 | peterhead
# processing record 446 | great bend
# processing record 447 | roald
# processing record 448 | pandan
# processing record 449 | severnyy
# processing record 450 | cayenne
# processing record 451 | halifax
# processing record 452 | high level
# processing record 453 | naliya
# processing record 454 | newport
# processing record 455 | shymkent
# processing record 456 | bonavista
# processing record 457 | barcelos
# processing record 458 | nizhniy tsasuchey
# processing record 459 | xinzhou
# processing record 460 | riyadh
# processing record 461 | vardo
# processing record 462 | shakawe
# processing record 463 | alofi
# city not found skipping....
# processing record 464 | kozelsk
# processing record 465 | filingue
# city not found skipping....
# processing record 466 | uruzgan
# processing record 467 | itarema
# processing record 468 | deputatskiy
# processing record 469 | hualmay
# processing record 470 | mandalgovi
# processing record 471 | ejea de los caballeros
# processing record 472 | lensk
# processing record 473 | nizwa
# processing record 474 | dwarka
# processing record 475 | la ronge
# city not found skipping....
# processing record 476 | reichenau
# processing record 477 | atessa
# processing record 478 | yanam
# city not found skipping....
# processing record 479 | priargunsk
# processing record 480 | tatawin
# processing record 481 | el jicaro
# processing record 482 | port blair
# city not found skipping....
# processing record 483 | augustow
# processing record 484 | palmer
# processing record 485 | bambanglipuro
# processing record 486 | keuruu
# processing record 487 | aquin
# processing record 488 | yaan
# processing record 489 | tall kayf
# processing record 490 | tokur
# processing record 491 | sitka
# processing record 492 | tubinskiy
# processing record 493 | petropavlovskoye
# processing record 494 | semirom
# processing record 495 | kosonsoy
# processing record 496 | malatya
# processing record 497 | saskatoon
# processing record 498 | kamina
# processing record 499 | hobyo
# processing record 500 | praya
# processing record 501 | osmena
# processing record 502 | bara
# processing record 503 | rio grande
# processing record 504 | launceston
# processing record 505 | thinadhoo
# processing record 506 | airai
# processing record 507 | marion
# processing record 508 | kenai
# processing record 509 | fort frances
# processing record 510 | pundaguitan
# processing record 511 | maningrida
# processing record 512 | neiafu
# processing record 513 | sinnamary
# processing record 514 | avera
# processing record 515 | san policarpo
# processing record 516 | sindor
# processing record 517 | turbat
# processing record 518 | muisne
# processing record 519 | mayo
# processing record 520 | port hardy
# city not found skipping....
# processing record 521 | soyo
# processing record 522 | ibotirama
# processing record 523 | pemberton
# processing record 524 | tumen
# processing record 525 | praia
# processing record 526 | burnie
# processing record 527 | arras
# processing record 528 | coahuayana
# processing record 529 | trairi
# processing record 530 | san francisco
# processing record 531 | iacu
# processing record 532 | padang
# processing record 533 | kamenka
# processing record 534 | chake chake
# processing record 535 | verkhneyarkeyevo
# processing record 536 | waitati
# processing record 537 | amga
# processing record 538 | ust-maya
# processing record 539 | sunderland
# processing record 540 | stornoway
# processing record 541 | vila velha
# processing record 542 | tahoua
# processing record 543 | gerash
# processing record 544 | yulara
# processing record 545 | nishihara
# processing record 546 | mikumi
# processing record 547 | weifang
# processing record 548 | les cayes
# processing record 549 | ancud
# processing record 550 | jyvaskyla
# processing record 551 | buchanan
# processing record 552 | sept-iles
# processing record 553 | stadtlohn
# processing record 554 | izumo
# processing record 555 | adamovka
# processing record 556 | kitimat
# processing record 557 | santa catarina de tepehuanes
# processing record 558 | mabaruma
# processing record 559 | belvedere marittimo
# processing record 560 | poronaysk
# processing record 561 | sola
# processing record 562 | reconquista
# processing record 563 | north platte

# %%
df = pd.DataFrame({'city': city_names, 'date': date, 'latitude': lat, 'Longitutude': lon, 'maximum Temperature': max_temp, 'Humidity': humidity, 'Cloudiness': cloudiness, 'Wind Speed': wind_speed, 'Country': country, 'Date': date})
df
# Out:
#                     city        date  latitude  Longitutude  \
# 0                Cascais  1605902846     38.70        -9.42
# 1                  Bluff  1605902846    -46.60       168.33
# 2                 Majene  1605902997     -3.54       118.97
# 3              Bathsheba  1605902998     13.22       -59.52
# 4                 Barrow  1605902999     71.29      -156.79
# ..                   ...         ...       ...          ...
# 558  Belvedere Marittimo  1605903657     39.62        15.86
# 559            Poronaysk  1605903658     49.22       143.12
# 560                 Sola  1605903659    -13.88       167.55
# 561          Reconquista  1605903660    -29.15       -59.65
# 562         North Platte  1605903662     41.12      -100.77
#
#      maximum Temperature  Humidity  Cloudiness  Wind Speed Country        Date
# 0                 292.59        55           0        3.10      PT  1605902846
# 1                 290.93        59          59        7.15      NZ  1605902846
# 2                 298.78        83         100        1.55      ID  1605902997
# 3                 300.15        83          75        5.10      BB  1605902998
# 4                 259.15        77          20        6.70      US  1605902999
# ..                   ...       ...         ...         ...     ...         ...
# 558               286.48        99         100        4.37      IT  1605903657
# 559               267.02        88         100        2.70      RU  1605903658
# 560               298.91        80          99        2.08      VU  1605903659
# 561               301.75        29           0        1.62      AR  1605903660
# 562               288.15        26           1        3.10      US  1605903662
#
# [563 rows x 10 columns]

# %%
# Save Data to csv
df.to_csv("Weather_part1.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
for city in cities:
    filter_df = df.loc[df["Humidity"]> 100]
    filter_df = filter_df.drop(["city"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-26fe67fb3536> in <module>
#       1 for city in cities:
#       2     filter_df = df.loc[df["Humidity"]> 100]
# ----> 3     filter_df = filter_df.drop(["city"])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['city'] not found in axis"

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
