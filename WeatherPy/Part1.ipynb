# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
##pip install citipy==0.0.5
# Out:
# Requirement already satisfied: citipy==0.0.5 in c:\users\jeawills\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\jeawills\anaconda3\lib\site-packages (from citipy==0.0.5) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json 
from pandas.io.json import json_normalize

from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 638

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_names = []
lat = []
lon =[]
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

print('Beginning Data Retrieval ')
print('----------------------')
record = 1
for city in cities:
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"
    response = requests.get(url).json()
    try:
        city_names.append(response['name'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt']) 
        print(f'processing record {record} | {city}')
        record +=1 
        time.sleep(1.1)
    except:
        print ('city not found skipping....')
# Out:
# Beginning Data Retrieval
# ----------------------
# processing record 1 | nikolskoye
# processing record 2 | tiarei
# processing record 3 | busselton
# processing record 4 | ixtapa
# processing record 5 | alofi
# processing record 6 | bethel
# processing record 7 | bluff
# processing record 8 | ribeira grande
# processing record 9 | egvekinot
# processing record 10 | kapaa
# processing record 11 | rikitea
# processing record 12 | argentan
# processing record 13 | bengkulu
# processing record 14 | rawson
# processing record 15 | carnarvon
# processing record 16 | vao
# processing record 17 | cherskiy
# processing record 18 | cidreira
# processing record 19 | bathsheba
# processing record 20 | beringovskiy
# processing record 21 | tigil
# processing record 22 | ushuaia
# processing record 23 | iqaluit
# city not found skipping....
# city not found skipping....
# processing record 24 | jamestown
# processing record 25 | sechura
# processing record 26 | bambous virieux
# processing record 27 | atuona
# processing record 28 | katsuura
# processing record 29 | haines junction
# processing record 30 | bredasdorp
# processing record 31 | severo-kurilsk
# processing record 32 | mataura
# processing record 33 | xiaolingwei
# processing record 34 | salinas
# processing record 35 | vaini
# processing record 36 | barrow
# processing record 37 | namatanai
# city not found skipping....
# processing record 38 | whitehorse
# city not found skipping....
# processing record 39 | port alfred
# processing record 40 | kemijarvi
# processing record 41 | qaanaaq
# processing record 42 | lata
# processing record 43 | east london
# processing record 44 | kuznechnoye
# processing record 45 | puerto ayora
# processing record 46 | apache junction
# processing record 47 | mahebourg
# processing record 48 | makakilo city
# processing record 49 | lamu
# processing record 50 | albany
# processing record 51 | isangel
# processing record 52 | chokurdakh
# processing record 53 | moses lake
# processing record 54 | pitimbu
# processing record 55 | ahipara
# processing record 56 | hithadhoo
# processing record 57 | cayenne
# processing record 58 | kushima
# processing record 59 | pueblo bello
# processing record 60 | airai
# processing record 61 | port macquarie
# processing record 62 | port shepstone
# processing record 63 | narsaq
# processing record 64 | raga
# processing record 65 | provideniya
# processing record 66 | ust-nera
# processing record 67 | victoria
# processing record 68 | ziyang
# processing record 69 | butaritari
# processing record 70 | puquio
# processing record 71 | georgetown
# processing record 72 | saint-pierre
# processing record 73 | buckeye
# processing record 74 | abu dhabi
# processing record 75 | soyo
# processing record 76 | thompson
# processing record 77 | tuatapere
# processing record 78 | luganville
# processing record 79 | algiers
# processing record 80 | sedalia
# processing record 81 | saint-philippe
# processing record 82 | vostochnyy
# processing record 83 | montrose
# processing record 84 | bone
# processing record 85 | san andres
# processing record 86 | ostrovnoy
# processing record 87 | nemuro
# city not found skipping....
# processing record 88 | kristianstad
# processing record 89 | booue
# city not found skipping....
# processing record 90 | ibra
# processing record 91 | kodiak
# processing record 92 | hermanus
# processing record 93 | grindavik
# processing record 94 | pakenham
# processing record 95 | valera
# city not found skipping....
# processing record 96 | muroto
# processing record 97 | lufilufi
# processing record 98 | ponta do sol
# processing record 99 | hobart
# processing record 100 | port lincoln
# processing record 101 | monticello
# city not found skipping....
# processing record 102 | plettenberg bay
# processing record 103 | kahului
# processing record 104 | tyulyachi
# processing record 105 | caconda
# processing record 106 | riyadh
# processing record 107 | broken hill
# processing record 108 | donskoye
# processing record 109 | tuktoyaktuk
# processing record 110 | seoul
# processing record 111 | katangli
# processing record 112 | gamba
# processing record 113 | kaeo
# city not found skipping....
# processing record 114 | boddam
# processing record 115 | taoudenni
# processing record 116 | longyearbyen
# processing record 117 | new norfolk
# processing record 118 | aljezur
# processing record 119 | turukhansk
# processing record 120 | lagoa
# processing record 121 | palembang
# processing record 122 | klaksvik
# processing record 123 | saldanha
# processing record 124 | sao jose da coroa grande
# processing record 125 | torbay
# processing record 126 | agirish
# processing record 127 | vostok
# processing record 128 | antofagasta
# processing record 129 | santa cruz
# processing record 130 | onguday
# processing record 131 | serenje
# processing record 132 | weyburn
# processing record 133 | charters towers
# processing record 134 | straumen
# processing record 135 | yaan
# processing record 136 | cape town
# processing record 137 | tasiilaq
# processing record 138 | nidadavole
# processing record 139 | dharchula
# processing record 140 | punta arenas
# processing record 141 | sinnamary
# processing record 142 | halifax
# city not found skipping....
# processing record 143 | yellowknife
# processing record 144 | tecoanapa
# processing record 145 | lahaina
# processing record 146 | clyde river
# processing record 147 | qarqin
# processing record 148 | san fernando
# processing record 149 | coquimbo
# processing record 150 | chuy
# processing record 151 | phrae
# processing record 152 | darnah
# processing record 153 | valdivia
# processing record 154 | guangyuan
# processing record 155 | northam
# processing record 156 | khorinsk
# processing record 157 | samarai
# city not found skipping....
# processing record 158 | bandarbeyla
# processing record 159 | segovia
# processing record 160 | vila franca do campo
# processing record 161 | pacific grove
# processing record 162 | maputo
# processing record 163 | ust-omchug
# processing record 164 | carballo
# city not found skipping....
# processing record 165 | padang
# processing record 166 | ardesen
# processing record 167 | kununurra
# processing record 168 | lavrentiya
# processing record 169 | ancud
# processing record 170 | asau
# processing record 171 | kainan
# processing record 172 | vardo
# processing record 173 | vaitape
# processing record 174 | pavlovka
# processing record 175 | lasa
# processing record 176 | khatanga
# processing record 177 | morondava
# city not found skipping....
# processing record 178 | abu samrah
# processing record 179 | chernyshevskiy
# processing record 180 | brae
# processing record 181 | binzhou
# city not found skipping....
# processing record 182 | iquique
# processing record 183 | rampura
# processing record 184 | helong
# city not found skipping....
# processing record 185 | cahul
# processing record 186 | magadan
# processing record 187 | alta floresta
# processing record 188 | griffith
# processing record 189 | miri
# processing record 190 | general pico
# processing record 191 | nanortalik
# processing record 192 | phek
# processing record 193 | flin flon
# processing record 194 | pucallpa
# processing record 195 | avarua
# processing record 196 | hofn
# processing record 197 | meulaboh
# processing record 198 | moctezuma
# processing record 199 | paamiut
# processing record 200 | vilhena
# city not found skipping....
# processing record 201 | khandyga
# city not found skipping....
# processing record 202 | srednekolymsk
# processing record 203 | sao filipe
# processing record 204 | escanaba
# processing record 205 | kaitangata
# processing record 206 | laguna
# processing record 207 | corn island
# processing record 208 | karratha
# city not found skipping....
# processing record 209 | nanyang
# processing record 210 | castro
# processing record 211 | pisco
# processing record 212 | pandan
# processing record 213 | saint-francois
# processing record 214 | champerico
# processing record 215 | waipawa
# processing record 216 | henties bay
# processing record 217 | tigzirt
# processing record 218 | minsk
# processing record 219 | ocala
# city not found skipping....
# processing record 220 | half moon bay
# processing record 221 | fairbanks
# processing record 222 | juba
# processing record 223 | sur
# processing record 224 | lebu
# processing record 225 | portland
# processing record 226 | faanui
# processing record 227 | aklavik
# processing record 228 | mar del plata
# processing record 229 | porto velho
# processing record 230 | along
# processing record 231 | alihe
# processing record 232 | paita
# processing record 233 | dakar
# processing record 234 | alice springs
# processing record 235 | port elizabeth
# processing record 236 | los llanos de aridane
# city not found skipping....
# processing record 237 | mortka
# processing record 238 | marawi
# processing record 239 | christchurch
# processing record 240 | ewa beach
# processing record 241 | changji
# processing record 242 | otavi
# processing record 243 | vestmannaeyjar
# processing record 244 | bilibino
# processing record 245 | roald
# city not found skipping....
# processing record 246 | te anau
# processing record 247 | celinac
# processing record 248 | batticaloa
# processing record 249 | luocheng
# processing record 250 | merauke
# processing record 251 | palana
# processing record 252 | borogontsy
# processing record 253 | saint george
# processing record 254 | arraias
# processing record 255 | doha
# processing record 256 | nouakchott
# processing record 257 | sambava
# city not found skipping....
# processing record 258 | pemberton
# processing record 259 | valle de allende
# processing record 260 | verkhnevilyuysk
# processing record 261 | waddan
# processing record 262 | codrington
# processing record 263 | altamira
# processing record 264 | kumluca
# processing record 265 | parabel
# processing record 266 | manicore
# processing record 267 | yantai
# processing record 268 | digha
# city not found skipping....
# processing record 269 | usinsk
# processing record 270 | pevek
# processing record 271 | jalingo
# processing record 272 | malatya
# processing record 273 | vila velha
# processing record 274 | naze
# processing record 275 | fort saint james
# processing record 276 | upernavik
# processing record 277 | nangka
# processing record 278 | baikunthpur
# processing record 279 | valparaiso
# processing record 280 | okha
# processing record 281 | wake forest
# processing record 282 | mount gambier
# processing record 283 | yeniseysk
# processing record 284 | demidov
# processing record 285 | celestun
# processing record 286 | honningsvag
# processing record 287 | arraial do cabo
# processing record 288 | grand gaube
# processing record 289 | umm lajj
# processing record 290 | segezha
# city not found skipping....
# processing record 291 | satipo
# processing record 292 | souillac
# processing record 293 | west wendover
# processing record 294 | lima
# processing record 295 | boralday
# processing record 296 | solok
# processing record 297 | bay roberts
# city not found skipping....
# city not found skipping....
# processing record 298 | chardara
# city not found skipping....
# processing record 299 | coihaique
# processing record 300 | geraldton
# processing record 301 | lukovetskiy
# processing record 302 | ust-tsilma
# processing record 303 | kruisfontein
# processing record 304 | lompoc
# processing record 305 | eyl
# processing record 306 | gweta
# processing record 307 | hilo
# processing record 308 | fortuna
# processing record 309 | manadhoo
# processing record 310 | gazalkent
# processing record 311 | gat
# processing record 312 | chulym
# processing record 313 | karpathos
# processing record 314 | north bend
# city not found skipping....
# processing record 315 | quelimane
# processing record 316 | savantvadi
# processing record 317 | hamilton
# processing record 318 | aykhal
# processing record 319 | coahuayana
# processing record 320 | tura
# processing record 321 | boquira
# city not found skipping....
# city not found skipping....
# processing record 322 | saskylakh
# processing record 323 | peace river
# processing record 324 | talcahuano
# processing record 325 | puerto del rosario
# processing record 326 | baykit
# processing record 327 | soe
# processing record 328 | nouna
# processing record 329 | bontang
# processing record 330 | alekseyevka
# processing record 331 | ilulissat
# processing record 332 | tezu
# processing record 333 | mecca
# processing record 334 | drovyanaya
# processing record 335 | dalbandin
# city not found skipping....
# processing record 336 | thoen
# processing record 337 | alta gracia
# city not found skipping....
# processing record 338 | talnakh
# processing record 339 | bloomingdale
# processing record 340 | carbondale
# processing record 341 | tuy hoa
# processing record 342 | salalah
# processing record 343 | esperance
# processing record 344 | garden city
# processing record 345 | agropoli
# city not found skipping....
# processing record 346 | deputatskiy
# city not found skipping....
# processing record 347 | markova
# processing record 348 | pringsewu
# processing record 349 | richards bay
# city not found skipping....
# processing record 350 | mudgee
# processing record 351 | humaita
# processing record 352 | hualmay
# processing record 353 | iskateley
# processing record 354 | turbat
# city not found skipping....
# processing record 355 | iralaya
# processing record 356 | huilong
# processing record 357 | san francisco
# processing record 358 | dikson
# city not found skipping....
# processing record 359 | saint-joseph
# processing record 360 | nantucket
# processing record 361 | san patricio
# processing record 362 | kudahuvadhoo
# processing record 363 | hovd
# city not found skipping....
# processing record 364 | graulhet
# processing record 365 | cockburn town
# processing record 366 | udachnyy
# processing record 367 | komsomolskiy
# processing record 368 | requena
# processing record 369 | husavik
# city not found skipping....
# processing record 370 | buchanan
# processing record 371 | chumikan
# processing record 372 | isla vista
# processing record 373 | auki
# processing record 374 | pathein
# processing record 375 | cabras
# processing record 376 | huadian
# processing record 377 | la ronge
# processing record 378 | ondjiva
# processing record 379 | silver city
# processing record 380 | baculin
# processing record 381 | huarmey
# processing record 382 | wiwili
# processing record 383 | namibe
# processing record 384 | aksarka
# processing record 385 | iberia
# processing record 386 | honiara
# processing record 387 | akdepe
# processing record 388 | ishim
# processing record 389 | ghanzi
# processing record 390 | labuhan
# processing record 391 | buraydah
# processing record 392 | vanavara
# processing record 393 | huesca
# city not found skipping....
# processing record 394 | mayumba
# city not found skipping....
# processing record 395 | port blair
# processing record 396 | aldan
# processing record 397 | santa fe do sul
# processing record 398 | sorland
# processing record 399 | sumbe
# processing record 400 | chhindwara
# processing record 401 | sabang
# city not found skipping....
# processing record 402 | winslow
# processing record 403 | yuanping
# processing record 404 | tomatlan
# processing record 405 | bowen
# processing record 406 | novotroitskaya
# processing record 407 | sioux lookout
# processing record 408 | kroya
# processing record 409 | sao joao da barra
# processing record 410 | solnechnyy
# processing record 411 | mogadishu
# processing record 412 | hirara
# processing record 413 | hohhot
# processing record 414 | pervomayskoye
# processing record 415 | broome
# processing record 416 | malibu
# processing record 417 | orlik
# processing record 418 | lorengau
# processing record 419 | guarapari
# processing record 420 | palm valley
# processing record 421 | lucapa
# processing record 422 | cabo san lucas
# processing record 423 | praia
# processing record 424 | iroquois falls
# processing record 425 | poum
# processing record 426 | talas
# processing record 427 | high level
# processing record 428 | takoradi
# processing record 429 | gojo
# processing record 430 | koumac
# processing record 431 | upington
# processing record 432 | hasaki
# processing record 433 | dankaur
# processing record 434 | palmas bellas
# processing record 435 | mount isa
# processing record 436 | alexandria
# processing record 437 | san ignacio
# city not found skipping....
# processing record 438 | florence
# processing record 439 | nanakuli
# processing record 440 | esterhazy
# city not found skipping....
# processing record 441 | redmond
# processing record 442 | altay
# processing record 443 | russell
# processing record 444 | ipixuna
# processing record 445 | leningradskiy
# processing record 446 | ponta delgada
# processing record 447 | rondonopolis
# processing record 448 | igrim
# processing record 449 | trat
# processing record 450 | tessalit
# processing record 451 | tafalla
# processing record 452 | planaltina
# processing record 453 | calabozo
# processing record 454 | artigas
# processing record 455 | arlit
# processing record 456 | fukue
# processing record 457 | kirakira
# city not found skipping....
# processing record 458 | smithers
# processing record 459 | kazan
# processing record 460 | maragogi
# processing record 461 | rio gallegos
# processing record 462 | tiksi
# processing record 463 | muros
# processing record 464 | sabya
# processing record 465 | nouadhibou
# city not found skipping....
# processing record 466 | banepa
# processing record 467 | kattivakkam
# processing record 468 | brusyliv
# processing record 469 | lithgow
# processing record 470 | chapais
# processing record 471 | mujiayingzi
# processing record 472 | linfen
# processing record 473 | korla
# processing record 474 | kavieng
# city not found skipping....
# processing record 475 | tiznit
# processing record 476 | boqueirao
# processing record 477 | karasjok
# processing record 478 | kysyl-syr
# processing record 479 | luderitz
# processing record 480 | finschhafen
# city not found skipping....
# processing record 481 | jiayuguan
# processing record 482 | zenzeli
# processing record 483 | comodoro rivadavia
# processing record 484 | lensk
# processing record 485 | chimbote
# processing record 486 | waingapu
# processing record 487 | warrnambool
# processing record 488 | cobija
# processing record 489 | santa
# processing record 490 | kenai
# processing record 491 | kawalu
# processing record 492 | mizdah
# processing record 493 | jijiga
# processing record 494 | havelock
# processing record 495 | constitucion
# processing record 496 | estelle
# processing record 497 | kieta
# processing record 498 | batsfjord
# processing record 499 | moyale
# processing record 500 | chacabuco
# processing record 501 | trelleborg
# processing record 502 | puerto madero
# processing record 503 | dhidhdhoo
# processing record 504 | boende
# processing record 505 | kavaratti
# processing record 506 | strangnas
# processing record 507 | corinto
# processing record 508 | salto
# processing record 509 | zlitan
# city not found skipping....
# processing record 510 | adrar
# processing record 511 | kinablangan
# processing record 512 | omboue
# processing record 513 | inhambane
# processing record 514 | sao domingos
# processing record 515 | mackay
# processing record 516 | ribas do rio pardo
# processing record 517 | yerbogachen
# processing record 518 | ayagoz
# processing record 519 | caceres
# processing record 520 | valle hermoso
# processing record 521 | mgandu
# processing record 522 | jodiya
# processing record 523 | ruwi
# processing record 524 | chara
# city not found skipping....
# processing record 525 | chiredzi
# processing record 526 | galle
# processing record 527 | quatre cocos
# city not found skipping....
# processing record 528 | boyolangu
# processing record 529 | majene
# processing record 530 | san jeronimo
# processing record 531 | gus-zheleznyy
# processing record 532 | tahta
# processing record 533 | nacala
# processing record 534 | sanchursk
# processing record 535 | flinders
# processing record 536 | ambon
# processing record 537 | urumqi
# processing record 538 | mezen
# processing record 539 | loukhi
# processing record 540 | barsovo
# processing record 541 | fort nelson
# processing record 542 | cheney
# processing record 543 | meadow lake
# processing record 544 | male
# processing record 545 | piacabucu
# processing record 546 | kangaatsiaq
# processing record 547 | karaton
# processing record 548 | amuntai
# processing record 549 | norman wells
# processing record 550 | dauriya
# processing record 551 | aquiraz
# processing record 552 | lewiston
# processing record 553 | hede
# processing record 554 | chipinge
# processing record 555 | kiryas joel
# city not found skipping....
# city not found skipping....
# processing record 556 | sainte-rose
# processing record 557 | tukrah
# processing record 558 | biloela
# processing record 559 | necochea
# processing record 560 | dire dawa
# city not found skipping....
# processing record 561 | krasnoturansk
# processing record 562 | pojuca
# processing record 563 | kiunga
# processing record 564 | mapastepec
# processing record 565 | kirovsk
# processing record 566 | voh
# processing record 567 | burns lake
# processing record 568 | kenora
# processing record 569 | touros
# processing record 570 | hami
# processing record 571 | san borja
# city not found skipping....
# processing record 572 | boromlya
# processing record 573 | guerrero negro
# processing record 574 | leninskoye
# processing record 575 | manaia
# processing record 576 | puerto maldonado
# city not found skipping....
# city not found skipping....
# processing record 577 | luquillo
# processing record 578 | conceicao da barra
# processing record 579 | maniitsoq
# processing record 580 | margate
# processing record 581 | portadown

# %%
city_data_pd = pd.DataFrame(city_data)

# Show Record Count
city_data_pd.count()
# Out:
# city                   0
# date                   0
# latitude               0
# Longitutude            0
# maximum Temperature    0
# Humidity               0
# Cloudiness             0
# Wind Speed             0
# Country                0
# Date                   0
# dtype: int64

# %%
df = pd.DataFrame({'city': city_names, 'date': date, 'latitude': lat, 'Longitutude': lon, 'maximum Temperature': max_temp, 'Humidity': humidity, 'Cloudiness': cloudiness, 'Wind Speed': wind_speed, 'Country': country, 'Date': date})
df
# Out:
#                     city        date  latitude  Longitutude  \
# 0                Cascais  1605902846     38.70        -9.42
# 1                  Bluff  1605902846    -46.60       168.33
# 2                 Majene  1605902997     -3.54       118.97
# 3              Bathsheba  1605902998     13.22       -59.52
# 4                 Barrow  1605902999     71.29      -156.79
# ..                   ...         ...       ...          ...
# 558  Belvedere Marittimo  1605903657     39.62        15.86
# 559            Poronaysk  1605903658     49.22       143.12
# 560                 Sola  1605903659    -13.88       167.55
# 561          Reconquista  1605903660    -29.15       -59.65
# 562         North Platte  1605903662     41.12      -100.77
#
#      maximum Temperature  Humidity  Cloudiness  Wind Speed Country        Date
# 0                 292.59        55           0        3.10      PT  1605902846
# 1                 290.93        59          59        7.15      NZ  1605902846
# 2                 298.78        83         100        1.55      ID  1605902997
# 3                 300.15        83          75        5.10      BB  1605902998
# 4                 259.15        77          20        6.70      US  1605902999
# ..                   ...       ...         ...         ...     ...         ...
# 558               286.48        99         100        4.37      IT  1605903657
# 559               267.02        88         100        2.70      RU  1605903658
# 560               298.91        80          99        2.08      VU  1605903659
# 561               301.75        29           0        1.62      AR  1605903660
# 562               288.15        26           1        3.10      US  1605903662
#
# [563 rows x 10 columns]

# %%
# Save Data to csv
df.to_csv("Weather_part1.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data = df[(df["Humidity"] > 100)]
city_data.head()
# Out:
# Empty DataFrame
# Columns: [city, date, latitude, Longitutude, maximum Temperature, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
